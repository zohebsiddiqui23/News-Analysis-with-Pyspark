# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("TopicModellingOnFinancialNewsData").getOrCreate()
# Out:
# 25/06/11 14:36:42 WARN Utils: Your hostname, Zohebs-MacBook-Pro.local resolves to a loopback address: 127.0.0.1; using 192.168.2.90 instead (on interface en0)
# 25/06/11 14:36:42 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.apache.spark.unsafe.Platform (file:/opt/homebrew/Caskroom/miniforge/base/envs/pyspark11/lib/python3.10/site-packages/pyspark/jars/spark-unsafe_2.12-3.2.1.jar) to constructor java.nio.DirectByteBuffer(long,int)
# WARNING: Please consider reporting this to the maintainers of org.apache.spark.unsafe.Platform
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# ...

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://192.168.2.90:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.2.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>TopicModellingOnFinancialNewsData</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df = spark.read.csv("financial_news_complete_content_updated.csv")

# %%
df.show()
# Out:
# +--------------------+-------------------+--------------------+--------------------+--------------------+--------------------+------------+
# |                 _c0|                _c1|                 _c2|                 _c3|                 _c4|                 _c5|         _c6|
# +--------------------+-------------------+--------------------+--------------------+--------------------+--------------------+------------+
# |              source|             author|                 url|         description|               title|             content|published_at|
# |    Business Insider|Kristine Villarroel|https://www.busin...|The market crash ...|20 vintage photos...|  Subscribe Newsl...|        null|
# |              Search|               null|                null|                null|                null|                null|        null|
# |            Business|               null|                null|                null|                null|                null|        null|
# ...

# %%
df = spark.read.option('header', 'true').csv('financial_news_complete_content.csv')
df.show(5)
# Out:
# +--------------------+-------------------+--------------------+--------------------+--------------------+--------------------+------------+
# |              source|             author|                 url|         description|               title|             content|published_at|
# +--------------------+-------------------+--------------------+--------------------+--------------------+--------------------+------------+
# |{'id': 'business-...|Kristine Villarroel|https://www.busin...|The market crash ...|20 vintage photos...|  Subscribe Newsl...|        null|
# |              Search|               null|                null|                null|                null|                null|        null|
# |            Business|               null|                null|                null|                null|                null|        null|
# |            Strategy|               null|                null|                null|                null|                null|        null|
# ...

# %%
# Method 1: With comprehensive options
df = spark.read \
    .option("header", "true") \
    .option("multiLine", "true") \
    .option("escape", '"') \
    .option("quote", '"') \
    .option("encoding", "UTF-8") \
    .option("inferSchema", "true") \
    .option("ignoreLeadingWhiteSpace", "true") \
    .option("ignoreTrailingWhiteSpace", "true") \
    .option("mode", "PERMISSIVE") \
    .option("columnNameOfCorruptRecord", "_corrupt_record") \
    .csv("financial_news_complete_content_updated.csv")

df.show(5, truncate=False)
# Out:
# +-------------------+------------------------------------------------+----------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ...
