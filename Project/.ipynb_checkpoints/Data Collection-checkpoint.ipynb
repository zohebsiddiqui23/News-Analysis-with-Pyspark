# %%
pip install newsapi-python
# Out:
# Collecting newsapi-python
#   Using cached newsapi_python-0.2.7-py2.py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: requests<3.0.0 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.12/site-packages (from newsapi-python) (2.32.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.12/site-packages (from requests<3.0.0->newsapi-python) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.12/site-packages (from requests<3.0.0->newsapi-python) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.12/site-packages (from requests<3.0.0->newsapi-python) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.12/site-packages (from requests<3.0.0->newsapi-python) (2025.4.26)
# Using cached newsapi_python-0.2.7-py2.py3-none-any.whl (7.9 kB)
# Installing collected packages: newsapi-python
# Successfully installed newsapi-python-0.2.7
# Note: you may need to restart the kernel to use updated packages.

# %%
from datetime import datetime
import pytz

# function to convert utc timestamp string into est tsring
def convert_utc_timestamp(utc_string):
    utc_time = datetime.strptime(utc_string, "%Y-%m-%dT%H:%M:%SZ")

    utc_time = pytz.utc.localize(utc_time)
    est_time = utc_time.astimezone(pytz.timezone('US/Eastern'))

    return est_time.strftime("%Y-%m-%d %H:%M:%S")

# %%
API_KEY="" #

# %%
from newsapi import NewsApiClient
import pandas as pd


# using newsapi client to get data (ref: https://newsapi.org/docs/client-libraries/python)
newsapi = NewsApiClient(api_key=API_KEY)

# creating list to store data, later to be used to create our data frame
sources = list()
authors = list()
urls = list()
descriptions = list()
titles = list()
contents = list()
published_at_dates = list()

# loop to set date from 9th May to 30th May, 2025.
for i in range(9, 30):
    
    temp = i 
    if i < 10:
        temp = f"0{i}"
    start_date = f'2025-05-{temp}'
    
    # get articles for a single date
    all_articles = newsapi.get_everything(q='finance OR stocks OR markets&',
                                          from_param=start_date,
                                          to=start_date,
                                          language='en',
                                          sort_by='relevancy',
                                          page=1,
                                          page_size=100)
    
    # after getting the data we iterate over each article and append the data into their respective list
    for article in all_articles['articles']:
        is_source = article.get('source')
        if is_source:
            source = str({"id": is_source.get("id"), "name": is_source.get("name")})
        author = article.get('author')
        url = article.get('url')
        description = article.get('description')
        title = article.get('title')
        content = article.get('content')
        published_at = article.get('publishedAt')
        if published_at:
            published_at = convert_utc_timestamp(published_at)
        
        sources.append(source)
        authors.append(author)
        urls.append(url)
        descriptions.append(description)
        titles.append(title)
        contents.append(content)
        published_at_dates.append(published_at)
    
    
# creating a dictionary to covert the data into a data frame
data = {
    "source": sources,
    "author": authors,
    "url": urls,
    "description": descriptions,
    "title": titles,
    "content": contents,
    "published_at": published_at_dates
}
df = pd.DataFrame(data=data)

# %%
df.head()
# Out:
#                                               source  \
# 0                {'id': None, 'name': 'Gizmodo.com'}
# 1  {'id': 'business-insider', 'name': 'Business I...
# 2        {'id': None, 'name': 'Yahoo Entertainment'}
# 3  {'id': 'business-insider', 'name': 'Business I...
# 4        {'id': None, 'name': 'Yahoo Entertainment'}
#
#                                              author  \
# 0                                       Joe Tilleli
# 1                                       Alex Nicoll
# 2  editorial-team@simplywallst.com (Simply Wall St)
# 3           jsor@businessinsider.com (Jennifer Sor)
# 4                                     Fatima Farooq
#
#                                                  url  \
# 0  https://gizmodo.com/wall-street-in-your-pocket...
# 1  https://www.businessinsider.com/apollo-global-...
# 2  https://finance.yahoo.com/news/3-top-dividend-...
# 3  https://markets.businessinsider.com/news/stock...
# 4  https://finance.yahoo.com/news/alphabet-inc-go...
#
#                                          description  \
# 0  Save 83% and an additional $30 when you sign u...
# 1  Banks are slowing their lending, opening doors...
# 2  With global markets reaching record highs on t...
# 3  "Do I think that stocks could go up more? The ...
# 4  We recently published a list of 15 AI Stocks T...
#
#                                                title  \
# 0  Wall Street in Your Pocket: The Tykr Stock Scr...
# 1  Apollo just set a goal to manage $1.2 trillion...
# 2                3 Top Dividend Stocks Yielding 5.6%
# 3  Investing in China's stock market is like 'pic...
# 4  Alphabet Inc. (GOOG): How AI Expansion and Fin...
#
#                                              content         published_at
# 0  Just starting out with stock trading can be an...  2024-10-01 14:18:47
# 1  Marc Rowan, CEO of ApolloArturo Holmes / Getty...  2024-10-01 18:01:22
# 2  With global markets reaching record highs on t...  2024-10-01 09:09:17
# 3  Investing in China over the long term is nothi...  2024-10-01 14:30:44
# 4  We recently published a list of 15 AI Stocks T...  2024-10-01 06:52:39

# %%
df.shape
# Out:
# (1500, 7)

# %%
df['content'].iloc[0]
# Out:
# 'Just starting out with stock trading can be an overwhelming experience. Knowing what stocks are good and bad and knowing when to buy or sell doesn’t come naturally. You can work with a financial advi… [+2251 chars]'

# %% [markdown]
# We retrived 1500 records successfully, from the above cell we can see that the data in the content column is incomplete. Thus our next step would be to scarpe the data using the url provided in every row and replace the content with the scraped content.

# %%
df.to_csv('financial_news_data.csv', index=False)

# %%
df.head()
# Out:
#                 source                                            author  \
# 0          Gizmodo.com                                       Joe Tilleli
# 1     Business Insider                                       Alex Nicoll
# 2  Yahoo Entertainment  editorial-team@simplywallst.com (Simply Wall St)
# 3     Business Insider           jsor@businessinsider.com (Jennifer Sor)
# 4  Yahoo Entertainment                                     Fatima Farooq
#
#                                                  url  \
# 0  https://gizmodo.com/wall-street-in-your-pocket...
# 1  https://www.businessinsider.com/apollo-global-...
# 2  https://finance.yahoo.com/news/3-top-dividend-...
# 3  https://markets.businessinsider.com/news/stock...
# 4  https://finance.yahoo.com/news/alphabet-inc-go...
#
#                                          description  \
# 0  Save 83% and an additional $30 when you sign u...
# 1  Banks are slowing their lending, opening doors...
# 2  With global markets reaching record highs on t...
# 3  "Do I think that stocks could go up more? The ...
# 4  We recently published a list of 15 AI Stocks T...
#
#                                                title  \
# 0  Wall Street in Your Pocket: The Tykr Stock Scr...
# 1  Apollo just set a goal to manage $1.2 trillion...
# 2                3 Top Dividend Stocks Yielding 5.6%
# 3  Investing in China's stock market is like 'pic...
# 4  Alphabet Inc. (GOOG): How AI Expansion and Fin...
#
#                                              content         published_at
# 0  Just starting out with stock trading can be an...  2024-10-01 14:18:47
# 1  Marc Rowan, CEO of ApolloArturo Holmes / Getty...  2024-10-01 18:01:22
# 2  With global markets reaching record highs on t...  2024-10-01 09:09:17
# 3  Investing in China over the long term is nothi...  2024-10-01 14:30:44
# 4  We recently published a list of 15 AI Stocks T...  2024-10-01 06:52:39

# %%
# df['source'].nunique()

# %%
df['source'].unique()
# Out:
# array(["{'id': None, 'name': 'Gizmodo.com'}",
#        "{'id': 'business-insider', 'name': 'Business Insider'}",
#        "{'id': None, 'name': 'Yahoo Entertainment'}",
#        "{'id': None, 'name': 'NPR'}",
#        "{'id': None, 'name': 'Biztoc.com'}",
#        "{'id': None, 'name': 'Forbes'}",
#        "{'id': None, 'name': 'Theregister.com'}",
#        "{'id': None, 'name': 'CNET'}",
#        "{'id': 'the-times-of-india', 'name': 'The Times of India'}",
#        "{'id': None, 'name': 'Quartz India'}",
#        "{'id': None, 'name': 'Torrentfreak.com'}",
#        "{'id': None, 'name': 'Skift'}",
#        '{\'id\': None, \'name\': "Investor\'s Business Daily"}',
#        "{'id': None, 'name': 'Japan Today'}",
#        "{'id': 'cbc-news', 'name': 'CBC News'}",
#        "{'id': None, 'name': 'CoinDesk'}",
#        "{'id': 'nbc-news', 'name': 'NBC News'}",
#        "{'id': None, 'name': 'International Business Times'}",
#        "{'id': None, 'name': 'Phandroid - News for Android'}",
#        "{'id': 'fortune', 'name': 'Fortune'}",
#        "{'id': None, 'name': 'Digital Trends'}",
#        "{'id': None, 'name': 'Slashdot.org'}",
#        "{'id': None, 'name': 'Phys.Org'}",
#        "{'id': None, 'name': 'AppleInsider'}",
#        "{'id': None, 'name': '9to5Mac'}",
#        "{'id': None, 'name': 'Digiday'}",
#        "{'id': 'techradar', 'name': 'TechRadar'}",
#        "{'id': None, 'name': 'Itsnicethat.com'}",
#        "{'id': None, 'name': 'Abnormalreturns.com'}",
#        "{'id': None, 'name': 'Android Central'}",
#        "{'id': 'time', 'name': 'Time'}",
#        "{'id': None, 'name': 'Fast Company'}",
#        "{'id': None, 'name': 'The New Yorker'}",
#        "{'id': 'abc-news-au', 'name': 'ABC News (AU)'}",
#        "{'id': None, 'name': 'GSMArena.com'}",
#        "{'id': None, 'name': 'BBC News'}",
#        "{'id': None, 'name': 'Ikeahackers.net'}",
#        "{'id': None, 'name': 'Deadline'}",
#        "{'id': None, 'name': '[Removed]'}",
#        "{'id': None, 'name': 'CNBC'}",
#        "{'id': None, 'name': 'Project Syndicate'}",
#        "{'id': None, 'name': 'Windows Central'}",
#        "{'id': None, 'name': 'VentureBeat'}",
#        "{'id': None, 'name': 'Power Technology'}",
#        "{'id': None, 'name': 'Hackaday'}",
#        "{'id': None, 'name': 'MarketWatch'}",
#        "{'id': None, 'name': 'SamMobile'}",
#        "{'id': None, 'name': 'MakeUseOf'}",
#        "{'id': None, 'name': 'Cracked.com'}",
#        "{'id': None, 'name': 'Politicopro.com'}",
#        "{'id': 'wired', 'name': 'Wired'}",
#        "{'id': None, 'name': 'Search Engine Journal'}",
#        "{'id': None, 'name': 'Ssrn.com'}",
#        "{'id': None, 'name': 'The Atlantic'}",
#        "{'id': None, 'name': 'Aschmelyun.com'}",
#        "{'id': 'abc-news', 'name': 'ABC News'}",
#        "{'id': None, 'name': 'Android Authority'}",
#        "{'id': None, 'name': 'Survivalblog.com'}",
#        "{'id': None, 'name': 'The Points Guy'}",
#        "{'id': None, 'name': 'Europa.eu'}",
#        "{'id': None, 'name': 'BusinessLine'}",
#        "{'id': None, 'name': 'Slate Magazine'}",
#        "{'id': None, 'name': 'Blogger.com'}",
#        "{'id': None, 'name': 'Economictimes.com'}",
#        "{'id': None, 'name': 'Twistedsifter.com'}",
#        "{'id': None, 'name': 'Ritholtz.com'}",
#        "{'id': None, 'name': 'IndieWire'}",
#        "{'id': None, 'name': 'Ra.co'}",
#        "{'id': None, 'name': 'Rlsbb.cc'}",
#        "{'id': None, 'name': 'VOA News'}",
#        "{'id': 'cbs-news', 'name': 'CBS News'}",
#        "{'id': None, 'name': 'Bitrebels.com'}",
#        "{'id': None, 'name': 'Rolling Stone'}",
#        "{'id': None, 'name': 'The Star Online'}",
#        "{'id': None, 'name': 'Rock Paper Shotgun'}",
#        "{'id': None, 'name': 'Wowebook.org'}",
#        "{'id': None, 'name': 'Github.io'}",
#        "{'id': None, 'name': 'Betalist.com'}",
#        "{'id': None, 'name': 'Bangkok Post'}",
#        "{'id': None, 'name': 'Harvard Business Review'}",
#        "{'id': None, 'name': 'Boredpanda.com'}",
#        "{'id': None, 'name': 'Pensacola News Journal'}",
#        "{'id': None, 'name': '/FILM'}",
#        "{'id': None, 'name': 'Mental Floss'}",
#        "{'id': None, 'name': 'Sinocism.com'}",
#        '{\'id\': None, \'name\': "Barron\'s"}',
#        "{'id': 'the-next-web', 'name': 'The Next Web'}",
#        "{'id': None, 'name': 'Socialmediaexplorer.com'}",
#        "{'id': None, 'name': 'Vox'}",
#        "{'id': 'al-jazeera-english', 'name': 'Al Jazeera English'}",
#        "{'id': None, 'name': 'Asteriskmag.com'}",
#        "{'id': None, 'name': 'Erickimphotography.com'}",
#        "{'id': None, 'name': 'Sherwood.news'}",
#        "{'id': None, 'name': 'GameSpot'}",
#        "{'id': None, 'name': 'Steveblank.com'}",
#        "{'id': None, 'name': 'Gothamist'}",
#        "{'id': None, 'name': 'UPI.com'}",
#        "{'id': None, 'name': 'Yanko Design'}",
#        "{'id': 'newsweek', 'name': 'Newsweek'}",
#        "{'id': None, 'name': 'XDA Developers'}",
#        "{'id': None, 'name': 'Boston Herald'}",
#        "{'id': None, 'name': 'CNA'}",
#        "{'id': 'the-verge', 'name': 'The Verge'}",
#        "{'id': None, 'name': 'MacRumors'}",
#        "{'id': None, 'name': 'Neowin'}",
#        "{'id': None, 'name': 'Globalsecurity.org'}",
#        "{'id': None, 'name': 'Awealthofcommonsense.com'}",
#        "{'id': 'rt', 'name': 'RT'}", "{'id': None, 'name': 'Verdict'}",
#        "{'id': 'polygon', 'name': 'Polygon'}",
#        "{'id': None, 'name': 'HYPEBEAST'}",
#        "{'id': None, 'name': 'Jalopnik'}",
#        "{'id': None, 'name': 'Hbs.edu'}",
#        "{'id': None, 'name': 'BetaNews'}",
#        "{'id': None, 'name': 'Radaronline.com'}",
#        "{'id': None, 'name': 'Techreport.com'}",
#        "{'id': None, 'name': 'Android Police'}",
#        "{'id': None, 'name': 'ArchDaily'}",
#        "{'id': None, 'name': 'Raw Story'}",
#        "{'id': None, 'name': 'Nakedcapitalism.com'}",
#        "{'id': None, 'name': 'Nathanzhao.cc'}",
#        "{'id': None, 'name': 'EURACTIV'}",
#        "{'id': 'espn', 'name': 'ESPN'}", "{'id': None, 'name': 'Ma.tt'}",
#        "{'id': 'bleacher-report', 'name': 'Bleacher Report'}",
#        "{'id': None, 'name': 'The Intercept'}",
#        "{'id': None, 'name': 'Ozbargain.com.au'}",
#        "{'id': 'financial-post', 'name': 'Financial Post'}",
#        "{'id': None, 'name': 'Molodtsov.me'}",
#        "{'id': None, 'name': 'Techmeme.com'}",
#        "{'id': None, 'name': 'Ship Technology'}",
#        "{'id': None, 'name': 'Poynter'}",
#        "{'id': None, 'name': 'The Cut'}",
#        "{'id': None, 'name': 'Dnyuz.com'}",
#        "{'id': None, 'name': 'Flowingdata.com'}",
#        "{'id': None, 'name': 'Coolmaterial.com'}",
#        "{'id': None, 'name': 'Techdirt'}",
#        "{'id': None, 'name': 'Upenn.edu'}",
#        "{'id': None, 'name': 'Thurrott.com'}",
#        "{'id': None, 'name': 'Scientific American'}",
#        "{'id': None, 'name': 'Electronicpaymentsinternational.com'}"],
#       dtype=object)

# %%
al-jazeera-english,the-times-of-india,fortune,espn
