# %%
pip install newsapi-python
# Out:
# Collecting newsapi-python
#   Using cached newsapi_python-0.2.7-py2.py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: requests<3.0.0 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.12/site-packages (from newsapi-python) (2.32.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.12/site-packages (from requests<3.0.0->newsapi-python) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.12/site-packages (from requests<3.0.0->newsapi-python) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.12/site-packages (from requests<3.0.0->newsapi-python) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.12/site-packages (from requests<3.0.0->newsapi-python) (2025.4.26)
# Using cached newsapi_python-0.2.7-py2.py3-none-any.whl (7.9 kB)
# Installing collected packages: newsapi-python
# Successfully installed newsapi-python-0.2.7
# Note: you may need to restart the kernel to use updated packages.

# %%
from datetime import datetime
import pytz

# function to convert utc timestamp string into est tsring
def convert_utc_timestamp(utc_string):
    utc_time = datetime.strptime(utc_string, "%Y-%m-%dT%H:%M:%SZ")

    utc_time = pytz.utc.localize(utc_time)
    est_time = utc_time.astimezone(pytz.timezone('US/Eastern'))

    return est_time.strftime("%Y-%m-%d %H:%M:%S")

# %%
API_KEY="" # add news api, API key here

# %%
from newsapi import NewsApiClient
import pandas as pd


# using newsapi client to get data (ref: https://newsapi.org/docs/client-libraries/python)
newsapi = NewsApiClient(api_key=API_KEY)

# creating list to store data, later to be used to create our data frame
sources = list()
authors = list()
urls = list()
descriptions = list()
titles = list()
contents = list()
published_at_dates = list()

# loop to set date from 9th May to 30th May, 2025.
for i in range(9, 30):
    
    temp = i 
    if i < 10:
        temp = f"0{i}"
    start_date = f'2025-05-{temp}'
    
    # get articles for a single date
    all_articles = newsapi.get_everything(q='finance OR stocks OR markets&',
                                          from_param=start_date,
                                          to=start_date,
                                          language='en',
                                          sort_by='relevancy',
                                          page=1,
                                          page_size=100)
    
    # after getting the data we iterate over each article and append the data into their respective list
    for article in all_articles['articles']:
        is_source = article.get('source')
        if is_source:
            source = str({"id": is_source.get("id"), "name": is_source.get("name")})
        author = article.get('author')
        url = article.get('url')
        description = article.get('description')
        title = article.get('title')
        content = article.get('content')
        published_at = article.get('publishedAt')
        if published_at:
            published_at = convert_utc_timestamp(published_at)
        
        sources.append(source)
        authors.append(author)
        urls.append(url)
        descriptions.append(description)
        titles.append(title)
        contents.append(content)
        published_at_dates.append(published_at)
    
    
# creating a dictionary to covert the data into a data frame
data = {
    "source": sources,
    "author": authors,
    "url": urls,
    "description": descriptions,
    "title": titles,
    "content": contents,
    "published_at": published_at_dates
}
df = pd.DataFrame(data=data)

# %%
df.head()
# Out:
#                                               source  \
# 0  {'id': 'business-insider', 'name': 'Business I...
# 1        {'id': None, 'name': 'Yahoo Entertainment'}
# 2                 {'id': None, 'name': 'Fresno Bee'}
# 3  {'id': 'business-insider', 'name': 'Business I...
# 4  {'id': 'business-insider', 'name': 'Business I...
#
#                                              author  \
# 0                               Kristine Villarroel
# 1  editorial-team@simplywallst.com (Simply Wall St)
# 2                                      Joshua Tehee
# 3               nredmond@insider.com (Nora Redmond)
# 4                               Grace Eliza Goodwin
#
#                                                  url  \
# 0  https://www.businessinsider.com/vintage-photos...
# 1  https://finance.yahoo.com/news/three-stocks-ma...
# 2  https://www.fresnobee.com/news/local/article30...
# 3  https://www.businessinsider.com/hsbc-loan-to-h...
# 4  https://www.businessinsider.com/white-house-sa...
#
#                                          description  \
# 0  The market crash of 1929 triggered the Great D...
# 1  The United States market has shown positive mo...
# 2  So far in 2025, 21 restaurants, markets and ot...
# 3  Since Trump announced his "Liberation Day" tar...
# 4  The White House says Trump's 10% baseline tari...
#
#                                                title  \
# 0  20 vintage photos show the 1929 stock market c...
# 1  Three Stocks That May Be Trading Below Their E...
# 2  Event center in Fresno closed due to unsanitar...
# 3  HSBC launched a loan specifically to help busi...
# 4  The White House says Trump's baseline 10% tari...
#
#                                              content         published_at
# 0  The widespread panic following the market cras...  2025-05-09 09:19:01
# 1  The United States market has shown positive mo...  2025-05-09 07:37:55
# 2  Reality Check is a Fresno Bee series holding t...  2025-05-09 15:30:00
# 3  Banking giant HSBC has launched a new financin...  2025-05-09 07:38:01
# 4  President Donald Trump wants to keep his basel...  2025-05-09 15:50:23

# %%
df.shape
# Out:
# (2086, 7)

# %%
df['content'].iloc[0]
# Out:
# 'The widespread panic following the market crash laid the foundations for the economic downturn of the 1930s.Bettmann/Bettmann Archive\r\n<ul><li>The 1929 stock market crash marked the beginning of the … [+11039 chars]'

# %% [markdown]
# We retrived 2086 records successfully, from the above cell we can see that the data in the content column is incomplete. Thus our next step would be to scarpe the data using the url provided in every row and replace the content with the scraped content.

# %%
df.to_csv('financial_news_data.csv', index=False)

# %%
df.head()
# Out:
#                                               source  \
# 0  {'id': 'business-insider', 'name': 'Business I...
# 1        {'id': None, 'name': 'Yahoo Entertainment'}
# 2                 {'id': None, 'name': 'Fresno Bee'}
# 3  {'id': 'business-insider', 'name': 'Business I...
# 4  {'id': 'business-insider', 'name': 'Business I...
#
#                                              author  \
# 0                               Kristine Villarroel
# 1  editorial-team@simplywallst.com (Simply Wall St)
# 2                                      Joshua Tehee
# 3               nredmond@insider.com (Nora Redmond)
# 4                               Grace Eliza Goodwin
#
#                                                  url  \
# 0  https://www.businessinsider.com/vintage-photos...
# 1  https://finance.yahoo.com/news/three-stocks-ma...
# 2  https://www.fresnobee.com/news/local/article30...
# 3  https://www.businessinsider.com/hsbc-loan-to-h...
# 4  https://www.businessinsider.com/white-house-sa...
#
#                                          description  \
# 0  The market crash of 1929 triggered the Great D...
# 1  The United States market has shown positive mo...
# 2  So far in 2025, 21 restaurants, markets and ot...
# 3  Since Trump announced his "Liberation Day" tar...
# 4  The White House says Trump's 10% baseline tari...
#
#                                                title  \
# 0  20 vintage photos show the 1929 stock market c...
# 1  Three Stocks That May Be Trading Below Their E...
# 2  Event center in Fresno closed due to unsanitar...
# 3  HSBC launched a loan specifically to help busi...
# 4  The White House says Trump's baseline 10% tari...
#
#                                              content         published_at
# 0  The widespread panic following the market cras...  2025-05-09 09:19:01
# 1  The United States market has shown positive mo...  2025-05-09 07:37:55
# 2  Reality Check is a Fresno Bee series holding t...  2025-05-09 15:30:00
# 3  Banking giant HSBC has launched a new financin...  2025-05-09 07:38:01
# 4  President Donald Trump wants to keep his basel...  2025-05-09 15:50:23

# %%
df['source'].nunique()
# Out:
# 194

# %%
df['source'].unique()
# Out:
# array(["{'id': 'business-insider', 'name': 'Business Insider'}",
#        "{'id': None, 'name': 'Yahoo Entertainment'}",
#        "{'id': None, 'name': 'Fresno Bee'}",
#        "{'id': None, 'name': 'Quartz India'}",
#        "{'id': None, 'name': 'Gizmodo.com'}",
#        "{'id': None, 'name': 'Forbes'}",
#        "{'id': None, 'name': 'MacRumors'}",
#        "{'id': None, 'name': 'Deadline'}",
#        "{'id': 'the-times-of-india', 'name': 'The Times of India'}",
#        "{'id': 'abc-news', 'name': 'ABC News'}",
#        "{'id': None, 'name': 'Comecruisewith.com'}",
#        "{'id': None, 'name': 'Upenn.edu'}",
#        "{'id': None, 'name': 'AppleInsider'}",
#        "{'id': None, 'name': 'Calculatedriskblog.com'}",
#        "{'id': None, 'name': 'TheStreet'}",
#        "{'id': None, 'name': 'Substack.com'}",
#        "{'id': None, 'name': 'Biztoc.com'}",
#        "{'id': None, 'name': 'The Daily Caller'}",
#        "{'id': None, 'name': 'CoinDesk'}",
#        "{'id': None, 'name': 'Android Police'}",
#        "{'id': None, 'name': 'GSMArena.com'}",
#        "{'id': None, 'name': 'Cointelegraph'}",
#        '{\'id\': None, \'name\': "Investor\'s Business Daily"}',
#        "{'id': 'time', 'name': 'Time'}",
#        "{'id': 'cbc-news', 'name': 'CBC News'}",
#        "{'id': None, 'name': 'Ritholtz.com'}",
#        "{'id': None, 'name': 'Motorfinanceonline.com'}",
#        "{'id': None, 'name': 'Ozbargain.com.au'}",
#        "{'id': None, 'name': 'International Business Times'}",
#        "{'id': None, 'name': 'The New Republic'}",
#        "{'id': None, 'name': 'Petrapalusova.com'}",
#        "{'id': None, 'name': 'Abnormalreturns.com'}",
#        "{'id': 'abc-news-au', 'name': 'ABC News (AU)'}",
#        "{'id': None, 'name': 'Slate Magazine'}",
#        "{'id': None, 'name': 'BusinessLine'}",
#        "{'id': None, 'name': 'Torrentfreak.com'}",
#        "{'id': None, 'name': 'Nakedcapitalism.com'}",
#        "{'id': 'al-jazeera-english', 'name': 'Al Jazeera English'}",
#        "{'id': None, 'name': 'Abortretry.fail'}",
#        "{'id': 'the-verge', 'name': 'The Verge'}",
#        "{'id': None, 'name': 'BBC News'}",
#        "{'id': None, 'name': 'Typeforyou.org'}",
#        "{'id': None, 'name': 'Thecooldown.com'}",
#        "{'id': None, 'name': 'HYPEBEAST'}",
#        "{'id': None, 'name': 'Naturalnews.com'}",
#        "{'id': None, 'name': 'TalkAndroid'}",
#        "{'id': 'mashable', 'name': 'Mashable'}",
#        "{'id': None, 'name': 'MarketWatch'}",
#        "{'id': None, 'name': 'CNA'}",
#        "{'id': None, 'name': 'Twistedsifter.com'}",
#        "{'id': None, 'name': 'New Atlas'}",
#        "{'id': None, 'name': 'Memeorandum.com'}",
#        "{'id': None, 'name': 'Hurriyet Daily News'}",
#        "{'id': None, 'name': 'NPR'}", "{'id': None, 'name': 'CNET'}",
#        "{'id': None, 'name': 'Android Central'}",
#        "{'id': None, 'name': 'Slashdot.org'}",
#        "{'id': None, 'name': 'Theregister.com'}",
#        "{'id': None, 'name': 'IndieWire'}", "{'id': None, 'name': 'Vox'}",
#        "{'id': 'cbs-news', 'name': 'CBS News'}",
#        "{'id': None, 'name': 'Gothamist'}",
#        "{'id': None, 'name': 'VentureBeat'}",
#        "{'id': None, 'name': 'Phys.Org'}",
#        "{'id': 'wired', 'name': 'Wired'}", "{'id': 'cnn', 'name': 'CNN'}",
#        "{'id': None, 'name': 'Techdirt'}",
#        "{'id': None, 'name': 'Techmeme.com'}",
#        "{'id': None, 'name': 'Android Authority'}",
#        "{'id': None, 'name': '9to5Mac'}",
#        "{'id': None, 'name': 'Windows Central'}",
#        "{'id': None, 'name': 'Project Syndicate'}",
#        "{'id': None, 'name': 'Etf.com'}",
#        "{'id': None, 'name': 'Electronicpaymentsinternational.com'}",
#        "{'id': None, 'name': 'Hotelmanagement-network.com'}",
#        "{'id': None, 'name': 'CFO Magazine'}",
#        "{'id': None, 'name': 'Twz.com'}",
#        "{'id': None, 'name': 'Nber.org'}",
#        "{'id': None, 'name': 'New York Post'}",
#        "{'id': 'usa-today', 'name': 'USA Today'}",
#        "{'id': 'espn', 'name': 'ESPN'}", "{'id': None, 'name': 'Skift'}",
#        "{'id': None, 'name': 'Nextcloud.com'}",
#        "{'id': None, 'name': 'Economictimes.com'}",
#        "{'id': None, 'name': 'Phandroid - News for Android'}",
#        "{'id': None, 'name': 'Science Daily'}",
#        "{'id': None, 'name': 'Ghacks Technology News'}",
#        "{'id': None, 'name': 'The New Yorker'}",
#        "{'id': None, 'name': 'The Intercept'}",
#        "{'id': None, 'name': 'Theaccountant-online.com'}",
#        "{'id': None, 'name': 'Search Engine Journal'}",
#        "{'id': None, 'name': 'Survivalblog.com'}",
#        "{'id': None, 'name': 'Boredpanda.com'}",
#        "{'id': None, 'name': 'Yanko Design'}",
#        "{'id': None, 'name': 'Metafilter.com'}",
#        "{'id': None, 'name': 'just-drinks.com'}",
#        "{'id': None, 'name': 'Just-food.com'}",
#        "{'id': None, 'name': 'Privatebankerinternational.com'}",
#        "{'id': None, 'name': 'Politicopro.com'}",
#        "{'id': None, 'name': 'Adweek'}",
#        "{'id': None, 'name': 'The Cut'}",
#        "{'id': 'fox-news', 'name': 'Fox News'}",
#        "{'id': None, 'name': 'Noupe.com'}",
#        "{'id': None, 'name': 'Investopedia'}",
#        "{'id': None, 'name': 'Mental Floss'}",
#        '{\'id\': None, \'name\': "Barron\'s"}',
#        "{'id': None, 'name': 'Cult of Mac'}",
#        "{'id': None, 'name': 'Leasinglife.com'}",
#        "{'id': None, 'name': 'International Business Times UK'}",
#        "{'id': None, 'name': 'Digiday'}",
#        "{'id': None, 'name': 'XDA Developers'}",
#        "{'id': None, 'name': 'Zamzar.com'}",
#        "{'id': None, 'name': 'Benzinga'}",
#        "{'id': None, 'name': 'Wnd.com'}",
#        "{'id': None, 'name': 'CleanTechnica'}",
#        "{'id': None, 'name': 'Ambcrypto.com'}",
#        "{'id': None, 'name': 'Erickimphotography.com'}",
#        "{'id': None, 'name': 'The Atlantic'}",
#        "{'id': None, 'name': 'The Daily Dot'}",
#        "{'id': 'rt', 'name': 'RT'}",
#        "{'id': None, 'name': 'ETF Daily News'}",
#        "{'id': None, 'name': 'Boston Herald'}",
#        "{'id': None, 'name': 'Neowin'}",
#        "{'id': None, 'name': 'PCWorld'}",
#        "{'id': None, 'name': 'Seeking Alpha'}",
#        "{'id': None, 'name': 'Oreilly.com'}",
#        "{'id': None, 'name': 'Post Magazine'}",
#        "{'id': None, 'name': 'Juancole.com'}",
#        "{'id': None, 'name': 'Softpagecms.com'}",
#        "{'id': None, 'name': 'Capitalandmain.com'}",
#        "{'id': None, 'name': 'Just Jared'}",
#        "{'id': None, 'name': 'Globalsecurity.org'}",
#        "{'id': None, 'name': 'Fox Business'}",
#        "{'id': None, 'name': 'Digitimes'}",
#        "{'id': None, 'name': 'Bangkok Post'}",
#        "{'id': None, 'name': 'Artofmanliness.com'}",
#        "{'id': None, 'name': 'Ioplus.nl'}",
#        "{'id': 'nbc-news', 'name': 'NBC News'}",
#        "{'id': None, 'name': 'Multifamilydive.com'}",
#        "{'id': None, 'name': 'ProPublica'}",
#        "{'id': None, 'name': 'Googleblog.com'}",
#        "{'id': None, 'name': 'Ndtvprofit.com'}",
#        "{'id': None, 'name': '/FILM'}",
#        "{'id': None, 'name': 'Artsjournal.com'}",
#        "{'id': None, 'name': 'First Showing'}",
#        "{'id': None, 'name': 'Internet'}",
#        "{'id': None, 'name': 'GameSpot'}",
#        '{\'id\': None, \'name\': "Paul Tan\'s Automotive News"}',
#        "{'id': 'the-next-web', 'name': 'The Next Web'}",
#        "{'id': None, 'name': 'Autoweek'}",
#        "{'id': 'techradar', 'name': 'TechRadar'}",
#        "{'id': None, 'name': 'Americanaffairsjournal.org'}",
#        "{'id': None, 'name': 'Japan Today'}",
#        "{'id': None, 'name': 'Finextra'}",
#        "{'id': None, 'name': 'Hvpandya.com'}",
#        "{'id': None, 'name': 'Voyageai.com'}",
#        "{'id': None, 'name': 'Awwwards.com'}",
#        "{'id': None, 'name': 'Hackaday'}",
#        "{'id': None, 'name': 'BetaNews'}",
#        "{'id': None, 'name': 'Grid.is'}",
#        "{'id': None, 'name': 'Cheezburger.com'}",
#        "{'id': None, 'name': 'Econbrowser.com'}",
#        "{'id': None, 'name': 'Hollywood Reporter'}",
#        "{'id': None, 'name': 'Whitecoatinvestor.com'}",
#        "{'id': None, 'name': 'Milliondollarjourney.com'}",
#        "{'id': None, 'name': 'Hillsdale.edu'}",
#        "{'id': None, 'name': 'The Takeout'}",
#        "{'id': None, 'name': 'Politicalwire.com'}",
#        "{'id': None, 'name': 'iLounge'}", "{'id': None, 'name': 'AOL'}",
#        "{'id': None, 'name': 'TechSpot'}",
#        "{'id': 'breitbart-news', 'name': 'Breitbart News'}",
#        "{'id': None, 'name': 'SamMobile'}",
#        "{'id': None, 'name': 'blogTO'}",
#        "{'id': None, 'name': 'Variety'}",
#        "{'id': None, 'name': 'Trendwatching.com'}",
#        "{'id': None, 'name': 'R-bloggers.com'}",
#        "{'id': None, 'name': 'Gwintrob.com'}",
#        "{'id': None, 'name': 'Everything-everywhere.com'}",
#        '{\'id\': None, \'name\': "Men\'s Journal"}',
#        "{'id': None, 'name': 'MacStories'}",
#        "{'id': None, 'name': 'Hubspot.com'}",
#        "{'id': None, 'name': 'Food52.com'}",
#        "{'id': None, 'name': 'Trendhunter.com'}",
#        "{'id': None, 'name': 'Wordpress.com'}",
#        "{'id': None, 'name': 'TMZ'}",
#        "{'id': None, 'name': 'Bankingdive.com'}",
#        "{'id': None, 'name': 'Crooksandliars.com'}",
#        "{'id': None, 'name': 'Awealthofcommonsense.com'}",
#        "{'id': None, 'name': 'Lwn.net'}",
#        "{'id': None, 'name': 'Restaurantdive.com'}",
#        "{'id': None, 'name': 'Raw Story'}",
#        "{'id': None, 'name': 'Rolling Stone'}",
#        "{'id': None, 'name': 'RealClearMarkets'}"], dtype=object)
